# %%
#7.1 
#task 1

time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

Low = []
Moderate = []
High = []

for study in time_data:
    if study[0] < 3:
        Low.append(study[0])
    elif 3<=study[0]<=5:
        Moderate.append(study[0])
    else:
        High.append(study[0])

print(f"Low = {Low}")
print(f"Moderate = {Moderate}")
print(f"High = {High}")
# Out:
# Low = [2.5, 1.5, 2.0, 2.5]
# Moderate = [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High = [5.5, 6.0]

# %%
#task2

Low_study_time = len(Low)
Moderate_study_time = len(Moderate)
High_study_time = len(High)

print(f"{Low_study_time} days had low study time")
print(f"{Moderate_study_time} days had moderate study time")
print(f"{High_study_time} days had high study time")
# Out:
# 4 days had low study time
# 9 days had moderate study time
# 2 days had high study time

# %%
#task5

import matplotlib.pyplot as plt 
study_hours = [3.5, 5.0, 2.5, 4.0, 1.5, 3.0, 5.5, 2.0, 4.5, 3.0, 6.0, 2.5, 4.0, 5.0, 3.5]
sleep_hours = [7.0, 6.5, 8.0, 6.0, 9.0, 7.5, 6.0, 8.5, 7.0, 7.5, 6.0, 8.0, 7.0, 6.5, 7.0]

plt.scatter(study_hours, sleep_hours, color="red")
plt.xlabel("study_hours")
plt.ylabel("sleep_hours")
plt.title("Study vs Sleep Pattern")
plt.show()

# %%
#8.1
#task 1

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
def sum_nested_list(nested_list):
    total = 0
    for items in nested_list:
        if isinstance(items, list):
            total += sum_nested_list(items)
        else:
            total += items
    return total

total = sum_nested_list(nested_list)
print(f"The total sum of all the numbers is {total}")
# Out:
# The total sum of all the numbers is 36

# %%
#task 2
def generate_permutations(s):
    if len(s) == 0:
        return [""]
    permutations = set()
    for i in range(len(s)):
        current = s[i]
        remaining = s[:i]+s[i+1:]
        for p in generate_permutations(remaining):
            permutations.add(current + p)
    return permutations

print(list(generate_permutations("abc")))
print(list(generate_permutations("aab")))
# Out:
# ['bca', 'cab', 'abc', 'cba', 'acb', 'bac']
# ['aab', 'baa', 'aba']

# %%
#task 3

directory = {
"file1.txt": 200,
"file2.txt": 300,
"subdir1": {
"file3.txt": 400,
"file4.txt": 100
},
"subdir2": {
"subsubdir1": {
"file5.txt": 250
},
"file6.txt": 150
}
}

def calculate_directory_size(directory):
    total = 0
    for kb in directory.values():
        if isinstance(kb, dict):
            total+=calculate_directory_size(kb)
        else:
            total += kb
    return total
print(f"The total kb in directory is {calculate_directory_size(directory)} kb")
# Out:
# The total kb in directory is 1400 kb

# %%
#task 8.2.1
#task 1

def min_coins(coins, amount):
    dp = [float("inf")] * (amount + 1)
    dp[0] = 0

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    if dp[amount] != float("inf"):
        return dp[amount]
    else:
        return -1

print(min_coins([5,5,1], 11))
# Out:
# 3

# %%
def longest_common_subsequence(s1, s2):
    m = len(s1)
    n = len(s2)
    dp = []
    for i in range(m + 1):
        dp.append([0] * (n + 1))

    for j in range(1, m + 1):
        for k in range(1, n + 1):
            if s1[j-1] == s2[k-1]:
                dp[j][k] = dp[j-1][k-1] + 1

            else:
                dp[j][k] = max(dp[j-1][k], dp[j][k-1])

    return dp[m][n]
print(longest_common_subsequence("abcde", "ace"))
# Out:
# 3

# %%
#task 8.2.1
#task 2

def min_coins(coins, amount):
    dp = [float("inf")] * (amount + 1)
    dp[0] = 0

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    if dp[amount] != float("inf"):
        return dp[amount]
    else:
        return -1

print(min_coins([5,5,1], 11))
# Out:
# 3

# %%
#task 3
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(values[i - 1] + dp[i - 1][w - weights[i - 1]], dp[i - 1][w])
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print(knapsack(weights, values, capacity))
# Out:
# 9
