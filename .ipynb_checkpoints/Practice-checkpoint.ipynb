# %%
mixed_list = [12, "hello", True]
mixed_list[0] = False
print(mixed_list[1])
print(mixed_list)
# Out:
# hello
# [False, 'hello', True]

# %%
colors = ('red', 'green', 'yello')
colors[0]
print(colors)
# Out:
# ('red', 'green', 'yello')

# %%
person = {'name':'John','age':30,'city':'Pittsburgh'}
person['name']
person.keys()
person.values()
person.items()
# Out:
# dict_items([('name', 'John'), ('age', 30), ('city', 'Pittsburgh')])

# %%
unique_numbers = {1,2,3,3,4}
print(unique_numbers)
# Out:
# {1, 2, 3, 4}

# %%
is_student = True
result = None
print(is_student)
# Out:
# True

# %%
num =5;
if num > 0:
    print("Positive")
elif num == 0:
    print("Zero")
else:
    print("Non-positive")
# Out:
# Positive
