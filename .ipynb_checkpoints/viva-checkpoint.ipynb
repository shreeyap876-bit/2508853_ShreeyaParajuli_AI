# %%
import numpy as np
import pandas as pd

# %%
#sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
#cost function
def cost(y, y_pred):
    return np.mean(-y * np.log(y_pred) - (1 - y) * np.log(1 - y_pred))

# %%
#Dataset laoding
import pandas as pd

def load_dataset(filename):
    df = pd.read_csv(filename)
    print("Dataset Loaded Successfully")
    return df
    
df = load_dataset("bank.csv")
# Out:
# Dataset Loaded Successfully
