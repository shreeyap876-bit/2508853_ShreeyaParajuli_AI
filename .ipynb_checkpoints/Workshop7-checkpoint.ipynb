# %%
import sklearn

# %%
import pandas as pd
2 # Load dataset
3 data = pd . read_csv (" student . csv")
4 # Feature matrix
5 X = data.drop ( columns =[" target "]) # Drop target column
6 print ( X . shape ) # ( n_samples , n_features )
# Out:
#   Cell In[8], line 3
#     3 data = pd . read_csv (" dataset . csv")
#       ^
# SyntaxError: invalid syntax
